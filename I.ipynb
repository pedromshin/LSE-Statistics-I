# %%
# The Normal Distribution and Ideas of Sampling

# provided the sample size is reasonably large, the distribution of the sample mean, will be (approximately) normal 
# regardless of the distribution of the original variable. This is known as the central limit theorem (CLT)

from ipynb.fs.defs._Formulas import normal_dist

normal_dist(mean=50, std_dev=8, num_samples=10000)
